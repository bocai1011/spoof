# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn import mixture
from sklearn import metrics
import sys
from scipy import stats
# %matplotlib inline

# %%
def prepareTrainSetRec():
    '''Each time the train data are loaded, all the features are calculated as the test set
    '''
    data = pd.read_csv('labeled_sina.csv')
    #import pdb;pdb.set_trace()
    dp = DataPrep()
    allorder = dp.computeEWAVBackward(data)
    hmmdata = dp.HMMPrep(allorder.copy())
    
    hmmdata['state']=0
    hmmdata.loc[(hmmdata['side']=='B')&(hmmdata['IsSpoof']==False),'state'] = 0
    hmmdata.loc[(hmmdata['side']=='S')&(hmmdata['IsSpoof']==False),'state'] = 1
    hmmdata.loc[(hmmdata['side']=='B')&(hmmdata['IsSpoof']==True),'state'] = 2
    hmmdata.loc[(hmmdata['side']=='S')&(hmmdata['IsSpoof']==True),'state'] = 3
    return hmmdata

# %%
def toMS(x):
    return ((x.hour*60+x.minute)*60+x.second)*1000000+x.microsecond
def timeDelta2MS(x):
    return (((x.hours*60+x.minutes)*60+x.seconds)*1000+x.milliseconds)*1000+x.microseconds
    
class DataPrep:
    ''' The parameters:
    1. isLean: whether we are dealing with data with more information. isLean=False, we have a richer data like the Training set. isLean=True, we have a lean data --only brief summary for each order
    2. decay_factor: a multiple of T_M (median trading gap)
    3. linger_factor: this is the multiple of the median trading gap. With this parameter, we will ignore all ordrers placed linger_factor*T_M ago
    '''
    def __init__(self,isLean=False,linger_factor = 40,decay_factor=5):        
        self.isLean = isLean
        self.linger_factor = linger_factor
        self.decay_factor = decay_factor
        self.medianT = 0 #the median of the trade interval
        
    def processDatafile(self,filename):
        data = pd.read_csv(filename)
        return self.processData(data)
    
    def processData(self,data,verbose=1):
        #import pdb;pdb.set_trace()
        if verbose>0:
            print '----Data cleaning----'
        if self.isLean:            
            allorder = self.cleanDataLean(data)
        else:
            allorder = self.cleanData(data)
    
        data = self.prepare(allorder)
        
        if verbose>0:
            print '---- Feature calculation----'
        #data = self.computeEWAVForward(data)
        allorder = self.computeEWAVBackward(data)
        #data = self.computeSEV(data)
        
        if verbose>0:
            print '----- Prepare for HMM------'
        data = self.HMMPrep(allorder.copy())
        
        return allorder,data
    
    def computeEWAVBackward(self,data):
        
        if len(data)<2:
            raise ValueError('data too short')
        
        #import pdb;pdb.set_trace()
        data['time diff'] = data['time diff'].fillna(24*3600*1000000)
        self.medianT = np.median(data['time diff'])
        T = self.medianT*self.decay_factor
        linger = self.medianT*self.linger_factor
        epsilon = sys.float_info.epsilon
        
        data['ewav_back canc buy'] = epsilon
        data['ewav_back canc sell'] = epsilon
        data['ewav_back exec buy'] = epsilon
        data['ewav_back exec sell'] = epsilon
    
        for ii in range(1,len(data)):
            coef = math.exp(-data.ix[ii]['time diff']/T) if data.ix[ii]['time diff']<=linger else 0
            data.loc[ii,'ewav_back canc buy'] = data.loc[ii,'cancelled buy']+data.loc[ii-1,'ewav_back canc buy']*coef
            data.loc[ii,'ewav_back canc sell'] = data.loc[ii,'cancelled sell']+data.loc[ii-1,'ewav_back canc sell']*coef
            data.loc[ii,'ewav_back exec buy'] = data.loc[ii,'exec buy']+data.loc[ii-1,'ewav_back exec buy']*coef
            data.loc[ii,'ewav_back exec sell'] = data.loc[ii,'exec sell']+data.loc[ii-1,'ewav_back exec sell']*coef
        ff = lambda x:x if x>epsilon else epsilon
        data['ewav_back canc buy'] = data['ewav_back canc buy'].map(ff)
        data['ewav_back canc sell'] = data['ewav_back canc sell'].map(ff)
        data['ewav_back exec buy'] = data['ewav_back exec buy'].map(ff)
        data['ewav_back exec sell'] = data['ewav_back exec sell'].map(ff)
      
        data['ewav_back buy/sell'] = data['ewav_back canc buy']/data['ewav_back canc sell'] 
        data['log ewav_back buy/sell'] = data['ewav_back buy/sell'].map(math.log)
        data['ewav_back sell/buy'] = data['ewav_back canc sell']/data['ewav_back canc buy']
                
        data['ewav_back buy exec+canc'] = data['ewav_back exec buy'] + data['ewav_back canc buy']
        data['ewav_back buy exec/total']=  data['ewav_back exec buy']/data['ewav_back buy exec+canc']       
       
        data['ewav_back sell exec+canc'] = data['ewav_back exec sell'] + data['ewav_back canc sell']
        data['ewav_back sell exec/total'] = data['ewav_back exec sell']/data['ewav_back sell exec+canc']
    
        return data
    
    def cleanDataLean(self,data):
        #data['q_exec'].fillna(0,inplace=True)
        data['q_exec'].fillna(0,inplace=True)
        data['execution_time'] = data['execution_time'].map(lambda x:pd.to_datetime(x))
        data['cancel_entry_time'] = data['cancel_entry_time'].map(lambda x:pd.to_datetime(x))
        data['order_entry_time'] = data['order_entry_time'].map(lambda x:pd.to_datetime(x))
        
        allorder = data
        allorder['prc*qty'] = allorder['avg_prc']        
        allorder['execution_time_last_ms'] = allorder['execution_time'].map(toMS)
        allorder['order_entry_time_ms'] = allorder['order_entry_time'].map(toMS)
        
        allorder['q_cancel'] = allorder['q_new'] - allorder['q_exec']
        allorder.set_index('orderid',inplace=True)
        allorder = allorder.sort('order_entry_time')
        return allorder
    
    def cleanData(self,data):
        data['q_exec'].fillna(0,inplace=True)
        data['execution_time'] = data['execution_time'].map(lambda x:pd.to_datetime(x))
        data['cancel_entry_time'] = data['cancel_entry_time'].map(lambda x:pd.to_datetime(x))
        data['order_entry_time'] = data['order_entry_time'].map(lambda x:pd.to_datetime(x))
        data['prc*qty'] = data['q_exec']*data['prc_exec']

        neworder = data.loc[data['order_type']=='NEW ORDER',:]
        exeorder = data.loc[data['order_type']=='EXECUTION',:]
        canorder = data.loc[data['order_type']=='CANCEL',:].copy()
    
        ############## Exclude those partial filled orders from cancel list
        #partialfill = set(canorder['orderid']).intersection(set(exeorder['orderid']))
        #canorder = canorder.loc[canorder['orderid'].isin(partialfill)==False,:]
        #####################################################################
   
        allorder = neworder[['id','orderid','symbol','q_new','price','order_entry_time','date','time','side']].set_index('orderid')
        gp = exeorder.groupby('orderid')
        tmp = gp.agg({'q_exec':np.sum,'prc*qty':np.sum})
        tmp['avg exe_prc'] = tmp['prc*qty']/tmp['q_exec']
        del tmp['prc*qty']
        allorder = allorder.join(tmp)
    #allorder = allorder.join(gp['execute_time'].agg({'first_exe_time':np.min,'last_exe_time':np.max}))
        allorder = allorder.join(gp['execution_time'].agg({'first_execution_time':np.min,'last_execution_time':np.max}))
        allorder['execution_time_first_ms'] = allorder['first_execution_time'].map(toMS)
        allorder['execution_time_last_ms'] = allorder['last_execution_time'].map(toMS)
        allorder['order_entry_time_ms'] = allorder['order_entry_time'].map(toMS)
    #gp = canorder.groupby('orderid')
        allorder = allorder.join(canorder.set_index('orderid')[['cancel_entry_time','canc_time']])
        allorder['q_exec'].fillna(0,inplace=True)
        allorder['q_cancel'] = allorder['q_new'] - allorder['q_exec']
        allorder = allorder.sort('order_entry_time')
        return allorder
    
    def prepare(self,allorder):
        ''' resort all the order according the the order entry time (canceled order) and exe time(filled order)
            Calculate the time difference
        '''
        fillorder = allorder.loc[allorder['q_exec']>0,['date','price','side','last_execution_time','execution_time_last_ms','q_exec']]
        fillorder['exec buy'] = fillorder['q_exec']
        fillorder['exec sell'] = fillorder['q_exec']
        fillorder.loc[fillorder['side']=='B','exec sell'] = 0
        fillorder.loc[fillorder['side']!='B','exec buy'] = 0
        fillorder = fillorder.rename(columns={'execution_time_last_ms':'microsecond','last_execution_time':'time'})

    #canorder = allorder.loc[allorder['q_cancel']>0,['date','price','side','order_entry_time','order_entry_time_ms','q_cancel']]
        canorder = allorder.loc[allorder['q_cancel']==allorder['q_new'],['date','price','side','order_entry_time','order_entry_time_ms','q_cancel']]
    #partially filled order discarded
    #import pdb;pdb.set_trace()
        canorder['cancelled buy'] = canorder['q_cancel']
        canorder['cancelled sell'] = canorder['q_cancel']
        canorder.loc[canorder['side']=='B','cancelled sell'] = 0.0
        canorder.loc[canorder['side']!='B','cancelled buy'] = 0.0
        canorder = canorder.rename(columns={'order_entry_time_ms':'microsecond','order_entry_time':'time'})

        fillorder['cancelled buy'] = 0
        fillorder['cancelled sell'] = 0
        canorder['exec buy'] = 0
        canorder['exec sell'] = 0
        del canorder['q_cancel']
        del fillorder['q_exec']
        data = fillorder.append(canorder)
        data = data.sort(['date','microsecond'])
        data = data.reset_index()
        #import pdb;pdb.set_trace()
        for dd in data['date'].unique():
            data.loc[data['date']==dd,'inventory'] = data.loc[data['date']==dd,'exec buy']-data.loc[data['date']==dd,'exec sell']
            data.loc[data['date']==dd,'inventory'] = data.loc[data['date']==dd,'inventory'].cumsum()
            data.loc[data['date']==dd,'time diff']= data.loc[data['date']==dd,'microsecond'].diff()*1. 
        data['time diff'] = data['time diff'].fillna(24*3600*1000000)
        return data
    
    def HMMPrep(self,df):
        #import pdb;pdb.set_trace()
        col = ['orderid','cancelled buy','exec sell','cancelled sell','exec buy','microsecond','price','side','time','date','inventory','time diff',
         'ewav_back canc buy','ewav_back canc sell','ewav_back exec buy','ewav_back exec sell','ewav_back buy/sell','ewav_back sell/buy']
        if 'IsSpoof' in df.columns:
            col +=['IsSpoof']
        df = df[col]
        del df['ewav_back exec buy']
        del df['ewav_back exec sell']
        # clean the data for ewav_back canc buy/sell and sell/buy
        # buy/sell will be just inverse of sell/buy, so we use one column buy/sell
        df.loc[(df['ewav_back canc buy']<1e-5)&(df['ewav_back canc sell']<1e-5),'ewav_back buy/sell']=1
        medianbs = df.loc[(df['ewav_back buy/sell']>0)&(df['ewav_back buy/sell']<np.inf),'ewav_back buy/sell'].median()
        maxbs = df.loc[(df['ewav_back buy/sell']>0)&(df['ewav_back buy/sell']<np.inf),'ewav_back buy/sell'].max()
        df.loc[df['ewav_back buy/sell']==np.inf,'ewav_back buy/sell'] = maxbs
        df.loc[df['ewav_back buy/sell']==0,'ewav_back buy/sell'] = 1/maxbs
        df.loc[:,'ewav_back buy/sell'] = df.loc[:,'ewav_back buy/sell'].map(np.log)
        
        ## Get the time difference, seems not contributing for now
        df['TimeDiff_back'] = np.nan
        df['TimeDiff_frwd'] = np.nan
        df['TimeDiff_min'] = np.nan
        #import pdb;pdb.set_trace()
        
        df = df.loc[(df['exec sell']>0)|(df['exec buy']>0),:].copy()
        if len(df)==0:
            return df
        buy = df.loc[df['side']=='B',:].copy()
        if len(buy)>0:
            for dd in buy['date'].unique():
            #import pdb;pdb.set_trace()
                tmp = buy.loc[buy['date']==dd,:]
                buy.loc[buy['date']==dd,'TimeDiff_back'] = buy.loc[buy['date']==dd,'microsecond'].diff(1).map(lambda x:np.abs(x))
                buy.loc[buy['date']==dd,'TimeDiff_frwd'] = buy.loc[buy['date']==dd,'microsecond'].diff(-1).map(lambda x:np.abs(x))
            #import pdb;pdb.set_trace()    
            buy['TimeDiff_frwd'].fillna(buy['TimeDiff_frwd'].max(),inplace=True)    
            buy['TimeDiff_back'].fillna(buy['TimeDiff_back'].max(),inplace=True)
            buy['TimeDiff_min'] = buy.apply(lambda x:min(x['TimeDiff_back'],x['TimeDiff_frwd']),axis=1)

        sell = df.loc[df['side']=='S',:].copy()
        if len(sell)>0:
            for dd in sell['date'].unique():
                tmp = sell.loc[sell['date']==dd,:]
                sell.loc[sell['date']==dd,'TimeDiff_back'] = sell.loc[sell['date']==dd,'microsecond'].diff(1).map(lambda x:np.abs(x))
                sell.loc[sell['date']==dd,'TimeDiff_frwd'] = sell.loc[sell['date']==dd,'microsecond'].diff(-1).map(lambda x:np.abs(x))
    
            sell['TimeDiff_frwd'].fillna(sell['TimeDiff_frwd'].max(),inplace=True)
            sell['TimeDiff_back'].fillna(sell['TimeDiff_back'].max(),inplace=True)
            sell['TimeDiff_min'] = sell.apply(lambda x:min(x['TimeDiff_back'],x['TimeDiff_frwd']),axis=1)

        newdf = buy.append(sell)
        newdf['date'] = newdf['date'].map(lambda x:pd.to_datetime(x))
        #newdf = newdf.sort(['date','microsecond'])
        df = newdf.sort()
        
        return df

# %%
from sklearn.ensemble import RandomForestClassifier
class RFModel:
    def __init__(self,n_estimators,max_depth):
        self.rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
        self.label_map = {}
        self.rev_map = {}
        
        #self.label_set = label_set
        
    def fit(self,x1,label1,x2,label2):
        ''' we assume x1,x2 are numpy arrays (1-d)
        '''
        label = np.array([0]*len(x1)+[1]*len(x2))
        self.label_map = {0:label1,1:label2}
        self.rev_map ={label1:0,label2:1}
        data = np.concatenate((x1,x2)).reshape((len(x1)+len(x2),1))
        self.rf.fit(data,label)      
        if False:
            self.showResult(x1,label1,x2,label2)
    
    def showResult(self,x1,label1,x2,label2):
        #import pdb;pdb.set_trace()
        plt.hist(np.array(x1),bins=100,alpha=0.5,normed=True)
        plt.hist(np.array(x2),bins=100,alpha=0.5,normed=True)
        tt = np.arange(-50,50,0.05)
        tt = tt.reshape((len(tt),1))
        proba = self.rf.predict_proba(tt)
        plt.plot(tt,proba[:,0],color='b')
        plt.plot(tt,proba[:,1],color='r')
        plt.show()
        
    def score(self,x,label):
        ''' give score in log prob for the class denoted by label
        '''
        proba = self.rf.predict_proba(np.array(x).reshape((len(x),1)))
        return np.log(proba[:,self.rev_map[label]])
    
    def prob(self,x,label):
        ''' give score in log prob for the class denoted by label
        '''
        proba = self.rf.predict_proba(np.array(x).reshape((len(x),1)))
        return proba[:,self.rev_map[label]]
    
    
class RFWrapper():
    def __init__(self,rf,label):
        self.rf = rf
        self.label= label
    def score(self,x):
        return self.rf.score(x,self.label)
    def prob(self,x):
        return self.rf.prob(x,self.label)

# %%
class HMM:
    def __init__(self,nState,TDFeaSet,featureSet,useAllFea,useDPGMM=True):
        '''
        recommended value for featureSet=['ewav_back buy/sell']
        '''
        self.TDFeaSet = TDFeaSet
        self.featureSet = featureSet
        self.useDPGMM = useDPGMM
        self.useAllFea = useAllFea
        #self.df = data
        self.nState = nState
        self.tp = None
        self.pi = None
        self.TDmodel = []
        self.RatioModel = []
    
    def train(self,df,show=False):
        self.pi = np.array(df.groupby('state').size()*1.0/len(df))
        
        df['next state'] = df['state'].shift(-1)    

        gp = df.groupby(['state','next state','date']).size()
        aa = gp.sum(level=[0,1])
        bb = gp.sum(level=0)*1.
        self.tp = aa/bb

        print '---- Transition prob:'
        print self.tp
        
        self.RatioModel = []
        
        ### RF model for ratio #############
        
        ratio0 = df.loc[df['state']==0,self.featureSet]
        ratio2 = df.loc[df['state']==2,self.featureSet]
        rf_buy = RFModel(n_estimators=10,max_depth=2)
        rf_buy.fit(ratio0,0,ratio2,2)
        
        ratio1 = df.loc[df['state']==1,self.featureSet]
        ratio3 = df.loc[df['state']==3,self.featureSet]
        rf_sell = RFModel(n_estimators=10,max_depth=2)
        rf_sell.fit(ratio1,1,ratio3,3)
        
        self.RatioModel=[RFWrapper(rf_buy,0),RFWrapper(rf_sell,1),RFWrapper(rf_buy,2),RFWrapper(rf_sell,3)]            
    
    def stateProb(self,obs):
        '''Give the estimate of the probablity of each state at each time instance
        '''
        rtlist = []
    
        nState = self.nState
        RatioModel = self.RatioModel
        
        for rt in RatioModel:    
            rtlist.append(list(rt.score(np.array(obs[self.featureSet])))) #low efficiency code
        
        rtprob = np.asmatrix(rtlist)

        distrprob = rtprob
        
        logtp = np.log(self.tp)
        logpi = np.log(self.pi)
    
        alpha = np.zeros((nState,len(obs)))
        beta = np.zeros((nState,len(obs)))
    
        isbuy = obs['side'].map(lambda x:int(x=='B'))
        issell = obs['side'].map(lambda x:int(x=='S'))
        validState = np.asmatrix([isbuy,issell,isbuy,issell]) # 0 means not valid
        dumb = -1e5 #used to fill for np.log(zero)
    
        alpha[:,0] = np.squeeze(np.asarray(distrprob[:,0])) + logpi
        for ii in range(1,len(obs)):
            for kk in range(nState):
                if validState[kk,ii]==0:
                    alpha[kk,ii] = dumb
                else:
                    tmp = alpha[:,ii-1] + logtp[:,kk]
                    maxtmp = np.max(tmp)
                    tmp = tmp - maxtmp
                    alpha[kk,ii] = maxtmp + np.log(np.sum(np.exp(tmp))) + distrprob[kk,ii]
        
        for ii in range(len(obs)-2,-1,-1):
            for kk in range(nState):
                if validState[kk,ii] == 0:
                    beta[kk,ii] = dumb
                else:
                    tmp = np.asarray(logtp[kk])+beta[:,ii+1]+np.squeeze(np.asarray(distrprob[:,ii+1]))
                    maxtmp = np.max(tmp)
                    tmp = tmp - maxtmp
                    beta[kk,ii] = maxtmp + np.log(np.sum(np.exp(tmp)))
            
        gamma = alpha+beta # not exactly the gamma
        maxgamma = np.max(gamma,0)
        gamma = gamma - np.kron(np.reshape(maxgamma,(1,len(obs))),np.ones((nState,1)))
        gamma = np.exp(gamma)
        sumgamma = np.kron(np.sum(gamma,0),np.ones((nState,1)))
        gamma = gamma/sumgamma   
        return gamma
    
    def predict(self,df):
        ''' needs more work,better return a dataframe
        '''
        #import pdb;pdb.set_trace()
        data = df.copy()
        prob = self.stateProb(data)
        pred = np.argmax(prob,0)
        pred_prob=np.max(prob,0)
        data['pred'] = pred
        data['pred_prob'] = pred_prob
        data['predSpoofing'] = data['pred'].map(lambda x:x>1)
        return data

# %%
def refine_df(df):
    syms = df[(df['mtype']=='Filled')|(df['mtype']=='PartialFill')]['symbol'].unique()
    return df[df['symbol'].isin(syms)]

# %%
def process_dera(ao):
    ao = ao[['acct','date','symbol','ordid','time','side','mtype','limitprice','ordqty','trdprice','trdqty']]
    ao = ao[ao['mtype'].isin(['NewOrder','CancelRequest','Filled','PartialFill'])]
    ao['time'] = ao['time'].str[2:]
    ao['mtype'].replace(['NewOrder','CancelRequest','Filled','PartialFill'],['NEW ORDER','CANCEL','EXECUTION','EXECUTION'],inplace=True)
    ao['side'].replace(['BY','SL'],['B','S'],inplace=True)
    ao['q_new'] = np.where(ao['mtype']=='NEW ORDER',ao['ordqty'],np.NaN)
    ao['order_entry_time'] = np.where(ao['mtype']=='NEW ORDER',ao['time'],np.NaN)
    ao['q_exec'] = np.where(ao['mtype']=='EXECUTION',ao['trdqty'],np.NaN)
    ao['execution_time'] = np.where(ao['mtype']=='EXECUTION',ao['time'],np.NaN)
    ao['prc_exec'] = np.where(ao['mtype']=='EXECUTION',ao['trdprice'],np.NaN)
    ao['q_cancel'] = np.where(ao['mtype']=='CANCEL',ao['ordqty'],np.NaN)
    ao['canc_time'] = np.where(ao['mtype']=='CANCEL',ao['time'],np.NaN)
    ao['price'] = np.where(ao['mtype']=='EXECUTION',ao['trdprice'],ao['limitprice'])
    ao[['time','order_entry_time','execution_time','canc_time']]= ao[['time','order_entry_time','execution_time','canc_time']].apply(pd.to_datetime)
    ao['cancel_entry_time'] = ao['canc_time']
    ao['avg_prc'] = ao['prc_exec']
    ao.rename(columns={'acct':'id','ordid':'orderid','mtype':'order_type'},inplace=True)
    return ao

# %%
df.columns
# Out:
# Index([u'date', u'orderid', u'id', u'order_time', u'side', u'symbol',
#        u'account', u'order_shares', u'orderstatus', u'tif', u'exec_shares',
#        u'exec_last_time', u'explicit_cxl_time', u'fill_rate', u'auto_cxl_time',
#        u'cxl_time', u'hidden'],
#       dtype='object')

# %%
def process_dera(df):
    df = df[['account','date','symbol','orderid','order_time','side','order_shares','exec_shares','exec_last_time','cxl_time']]
    ret = pd.DataFrame(columns=['account','date','symbol','orderid','side','price','order_type','q_new','q_exec','q_cancel','order_entry_time','execution_time','canc_time'])
    tmp = pd.DataFrame(columns=['account','date','symbol','orderid','side','price','order_type','q_new','q_exec','q_cancel','order_entry_time','execution_time','canc_time'])
    for i in range(len(df)):
        tmp.loc[0] =

# %%
traindf = prepareTrainSetRec()   
mm = HMM(nState=4,TDFeaSet=['TimeDiff_frwd','TimeDiff_back'],featureSet=['ewav_back buy/sell'],useAllFea=False,useDPGMM=True)
mm.train(traindf)
# Out:
# /qau/share/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---- Transition prob:
# state  next state
# 0      0.0           0.706235
#        1.0           0.161871
#        2.0           0.026379
#        3.0           0.105516
# 1      0.0           0.217391
#        1.0           0.653673
#        2.0           0.076462
#        3.0           0.052474
# 2      0.0           0.107143
#        1.0           0.202381
#        2.0           0.678571
#        3.0           0.011905
# 3      0.0           0.190104
#        1.0           0.117188
#        2.0           0.018229
#        3.0           0.674479
# dtype: float64
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:228: FutureWarning: sort(....) is deprecated, use sort_index(.....)

# %%
dp = DataPrep(True)
res = pd.DataFrame()
total_spoof = 0
total_trades = 0

for sym in df['symbol'].unique():
    data = df[df['symbol']==sym]
    if len(data)<30:
        continue
    data = process_simplex(data)
    xx,hmmdata = dp.processData(data,verbose=0)
    if len(hmmdata)>=3:
        tmp = mm.predict(hmmdata)
        cur_spoof = len(tmp[tmp['predSpoofing']])
        total_spoof += cur_spoof
        res = res.append(tmp)
        total_trades += len(hmmdata)
        print 'ID={}, number of spoofing trade = {}, total trades = {}'.format(sym,cur_spoof,len(hmmdata))
        
print 'total finding ={}'.format(total_spoof)
print 'total trades = {}'.format(total_trades)
res.to_csv('0610.csv')
# Out:
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:100: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:165: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /qau/share/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:228: FutureWarning: sort(....) is deprecated, use sort_index(.....)
# ID=FRAN_16_2015.06.19_Put, number of spoofing trade = 0, total trades = 7
# ID=USO_20_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=AMBA_85_2015.08.21_Call, number of spoofing trade = 1, total trades = 5
# ID=GLD_113_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_205.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_630_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=SPY_204_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=SPY_210_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_211_2015.06.19_Call, number of spoofing trade = 1, total trades = 9
# ID=QQQ_109_2015.06.19_Call, number of spoofing trade = 1, total trades = 6
# ID=QQQ_110_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=QQQ_106_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=SPY_210_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=AAPL_126_2015.06.12_Call, number of spoofing trade = 0, total trades = 32
# ID=AAPL_127_2015.06.26_Call, number of spoofing trade = 1, total trades = 28
# ID=AAPL_130_2015.07.17_Call, number of spoofing trade = 0, total trades = 24
# ID=AAPL_131_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=AAPL_128_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=AAPL_130_2015.06.19_Put, number of spoofing trade = 2, total trades = 31
# ID=AAPL_128_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=AAPL_135_2015.06.19_Call, number of spoofing trade = 0, total trades = 15
# ID=AAPL_128_2015.06.12_Put, number of spoofing trade = 1, total trades = 31
# ID=TSLA_250_2015.06.19_Call, number of spoofing trade = 3, total trades = 9
# ID=TSLA_257.5_2015.06.12_Call, number of spoofing trade = 7, total trades = 19
# ID=NFLX_620_2015.06.12_Put, number of spoofing trade = 0, total trades = 17
# ID=TSLA_250_2015.06.12_Put, number of spoofing trade = 2, total trades = 74
# ID=TSLA_250_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=GPRO_55_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=GPRO_60_2015.07.17_Call, number of spoofing trade = 1, total trades = 6
# ID=ESPR_95_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=TBT_50_2015.06.12_Call, number of spoofing trade = 0, total trades = 11
# ID=TSLA_252.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 10
# ID=TSLA_267.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=VOD_38_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=NFLX_660_2015.06.12_Call, number of spoofing trade = 0, total trades = 39
# ID=GPRO_60_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=GPRO_57.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=TSLA_255_2015.06.12_Put, number of spoofing trade = 0, total trades = 23
# ID=NFLX_650_2015.06.12_Call, number of spoofing trade = 0, total trades = 53
# ID=AAPL_130_2015.06.19_Call, number of spoofing trade = 0, total trades = 17
# ID=AMZN_400_2016.01.15_Put, number of spoofing trade = 0, total trades = 4
# ID=AMZN_422.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 14
# ID=FB_90_2015.09.18_Call, number of spoofing trade = 1, total trades = 21
# ID=GLD_114.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=MNKD_3_2016.01.15_Call, number of spoofing trade = 0, total trades = 10
# ID=MNKD_4_2016.01.15_Call, number of spoofing trade = 0, total trades = 5
# ID=MNKD_4_2015.06.19_Call, number of spoofing trade = 0, total trades = 20
# ID=MNKD_2_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=IWM_124_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=NFLX_630_2015.06.12_Put, number of spoofing trade = 0, total trades = 17
# ID=GPRO_60_2015.06.12_Put, number of spoofing trade = 1, total trades = 22
# ID=NFLX_645_2015.06.12_Call, number of spoofing trade = 2, total trades = 37
# ID=AMBA_115_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_630_2015.06.19_Put, number of spoofing trade = 3, total trades = 17
# ID=NFLX_670_2015.06.19_Call, number of spoofing trade = 0, total trades = 44
# ID=NFLX_640_2015.06.12_Put, number of spoofing trade = 0, total trades = 22
# ID=AMBA_110_2015.06.12_Put, number of spoofing trade = 0, total trades = 5
# ID=TSLA_250_2015.06.12_Call, number of spoofing trade = 1, total trades = 24
# ID=NEM_26_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_632.5_2015.06.12_Put, number of spoofing trade = 3, total trades = 7
# ID=AAPL_125_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_700_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=NFLX_660_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=NFLX_647.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 24
# ID=GOOG_530_2015.06.19_Call, number of spoofing trade = 0, total trades = 9
# ID=AAPL_129_2015.06.12_Call, number of spoofing trade = 1, total trades = 40
# ID=AAPL_125_2015.08.21_Call, number of spoofing trade = 4, total trades = 7
# ID=AAPL_131_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=GOOGL_545_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=AAPL_130_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_210_2015.06.19_Call, number of spoofing trade = 1, total trades = 14
# ID=LNKD_215_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=TSLA_247.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 16
# ID=TBT_50_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_652.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 15
# ID=ONVO_3_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=ONVO_4_2015.06.19_Call, number of spoofing trade = 0, total trades = 38
# ID=AAPL_110_2016.01.15_Call, number of spoofing trade = 1, total trades = 5
# ID=TLT_115.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 10
# ID=FB_80_2015.06.19_Put, number of spoofing trade = 1, total trades = 5
# ID=HRTX_15_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=AAPL_130_2015.07.02_Call, number of spoofing trade = 0, total trades = 3
# ID=INVN_14_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=AAPL_129_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=LLY_82.5_2015.08.21_Call, number of spoofing trade = 0, total trades = 3
# ID=MFC_18_2015.09.18_Call, number of spoofing trade = 0, total trades = 8
# ID=RHT_80_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=LITB_5_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=LLY_75_2016.01.15_Call, number of spoofing trade = 0, total trades = 8
# ID=AAPL_127_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=SPY_209_2015.06.30_Put, number of spoofing trade = 0, total trades = 11
# ID=RH_100_2015.06.19_Call, number of spoofing trade = 0, total trades = 12
# ID=AMZN_435_2015.06.12_Call, number of spoofing trade = 0, total trades = 31
# ID=UAL_52.5_2015.07.17_Call, number of spoofing trade = 1, total trades = 5
# ID=AAL_42_2015.08.21_Call, number of spoofing trade = 0, total trades = 4
# ID=FCX_22_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=IBM_170_2015.06.19_Call, number of spoofing trade = 0, total trades = 16
# ID=IBM_175_2015.08.21_Call, number of spoofing trade = 1, total trades = 4
# ID=AZN_70_2015.10.16_Call, number of spoofing trade = 0, total trades = 3
# ID=ALLY_23_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=JCI_55_2015.10.16_Call, number of spoofing trade = 0, total trades = 3
# ID=FXI_50_2015.08.21_Call, number of spoofing trade = 1, total trades = 4
# ID=NFLX_640_2015.06.19_Put, number of spoofing trade = 0, total trades = 7
# ID=GOOGL_550_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_560_2015.07.02_Put, number of spoofing trade = 0, total trades = 8
# ID=NFLX_640_2015.06.12_Call, number of spoofing trade = 2, total trades = 35
# ID=GOOGL_550_2015.06.12_Call, number of spoofing trade = 1, total trades = 13
# ID=PCLN_1180_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=PCLN_1197.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=MU_25_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_750_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_625_2015.06.19_Call, number of spoofing trade = 0, total trades = 11
# ID=NFLX_650_2015.06.12_Put, number of spoofing trade = 1, total trades = 56
# ID=NFLX_655_2015.06.12_Put, number of spoofing trade = 0, total trades = 83
# ID=FXI_48.5_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=AAPL_140_2015.08.21_Call, number of spoofing trade = 0, total trades = 4
# ID=IWM_126_2015.06.12_Call, number of spoofing trade = 0, total trades = 11
# ID=NFLX_650_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_128_2015.06.12_Call, number of spoofing trade = 2, total trades = 51
# ID=TBT_50_2015.06.12_Put, number of spoofing trade = 0, total trades = 16
# ID=SPY_209.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 7
# ID=SPY_209.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 16
# ID=SPY_211.5_2015.06.19_Call, number of spoofing trade = 1, total trades = 6
# ID=SPY_212_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=VXX_19_2015.06.26_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_670_2015.06.12_Call, number of spoofing trade = 0, total trades = 12
# ID=GLD_112_2015.08.21_Call, number of spoofing trade = 0, total trades = 11
# ID=SPY_210_2015.06.19_Put, number of spoofing trade = 0, total trades = 31
# ID=NFLX_600_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=NFLX_580_2015.06.19_Put, number of spoofing trade = 4, total trades = 4
# ID=FXY_78_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=TSLA_247.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=TSLA_260_2015.06.12_Call, number of spoofing trade = 0, total trades = 13
# ID=FB_81_2015.06.12_Call, number of spoofing trade = 0, total trades = 25
# ID=MSFT_43_2015.10.16_Put, number of spoofing trade = 0, total trades = 3
# ID=GPRO_59_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=TSLA_250_2015.06.19_Put, number of spoofing trade = 0, total trades = 12
# ID=IWM_129_2015.07.17_Call, number of spoofing trade = 1, total trades = 28
# ID=FB_82_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=GPRO_40_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=TSLA_255_2015.06.19_Call, number of spoofing trade = 2, total trades = 20
# ID=NFLX_625_2015.06.12_Put, number of spoofing trade = 2, total trades = 21
# ID=PCLN_1180_2015.06.12_Call, number of spoofing trade = 0, total trades = 35
# ID=NFLX_647.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 13
# ID=AAPL_127_2015.06.12_Call, number of spoofing trade = 0, total trades = 18
# ID=TPX_70_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=GILD_110_2015.11.20_Call, number of spoofing trade = 0, total trades = 7
# ID=FB_100_2016.01.15_Call, number of spoofing trade = 0, total trades = 4
# ID=JNJ_110_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=PCLN_1190_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=UVXY_41_2015.06.12_Put, number of spoofing trade = 0, total trades = 8
# ID=SPY_213_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_211_2015.06.12_Call, number of spoofing trade = 0, total trades = 7
# ID=TSLA_240_2015.07.17_Put, number of spoofing trade = 0, total trades = 19
# ID=AAPL_130_2015.06.12_Put, number of spoofing trade = 0, total trades = 15
# ID=ATVI_26_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_131_2015.06.26_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_210_2015.06.12_Call, number of spoofing trade = 1, total trades = 19
# ID=MA_90_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=TSLA_240_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_720_2015.06.19_Call, number of spoofing trade = 0, total trades = 34
# ID=AAPL_135_2015.08.21_Call, number of spoofing trade = 0, total trades = 4
# ID=GILD_120_2015.11.20_Call, number of spoofing trade = 2, total trades = 5
# ID=DIS_110_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=LL_22_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=GLD_115_2015.06.12_Call, number of spoofing trade = 1, total trades = 3
# ID=AAPL_128_2015.06.26_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_127_2015.06.26_Put, number of spoofing trade = 0, total trades = 9
# ID=TSLA_255_2015.07.17_Call, number of spoofing trade = 1, total trades = 4
# ID=AAPL_126_2015.06.26_Call, number of spoofing trade = 0, total trades = 16
# ID=IWM_125.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=SPY_212_2015.06.12_Put, number of spoofing trade = 1, total trades = 7
# ID=SAN_5_2016.01.15_Call, number of spoofing trade = 0, total trades = 6
# ID=DIS_115_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_129_2015.06.12_Put, number of spoofing trade = 1, total trades = 15
# ID=AAPL_129_2015.06.26_Call, number of spoofing trade = 0, total trades = 8
# ID=SPY_209_2015.06.19_Put, number of spoofing trade = 0, total trades = 16
# ID=NFLX_645_2015.06.12_Put, number of spoofing trade = 0, total trades = 37
# ID=NFLX_695_2015.06.19_Call, number of spoofing trade = 0, total trades = 43
# ID=NFLX_655_2015.06.12_Call, number of spoofing trade = 0, total trades = 24
# ID=NFLX_645_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=MNKD_3_2017.01.20_Call, number of spoofing trade = 0, total trades = 6
# ID=DIA_180.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=PCLN_1172.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=TSLA_260_2015.06.12_Put, number of spoofing trade = 0, total trades = 6
# ID=NFLX_725_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_667.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=TSLA_265_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=BIDU_207.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=PCLN_1050_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=CL_66_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=AMZN_425_2015.06.12_Call, number of spoofing trade = 0, total trades = 12
# ID=URBN_35_2015.06.19_Put, number of spoofing trade = 0, total trades = 9
# ID=TSLA_255_2015.06.12_Call, number of spoofing trade = 1, total trades = 40
# ID=BABA_90_2015.06.19_Call, number of spoofing trade = 1, total trades = 6
# ID=AMGN_155_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=SPY_211.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_214_2015.08.21_Call, number of spoofing trade = 2, total trades = 5
# ID=GPRO_55_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_715_2015.06.12_Call, number of spoofing trade = 0, total trades = 35
# ID=BABA_90_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=SPY_208_2015.06.30_Put, number of spoofing trade = 1, total trades = 8
# ID=BIDU_205_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=SPY_205_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=SPY_210.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=MNKD_3.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_635_2015.06.12_Put, number of spoofing trade = 0, total trades = 6
# ID=NFLX_620_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=IWM_125_2015.06.12_Put, number of spoofing trade = 0, total trades = 5
# ID=MDY_230_2016.01.15_Put, number of spoofing trade = 0, total trades = 4
# ID=AAPL_140_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=ASPS_20_2015.07.17_Call, number of spoofing trade = 0, total trades = 11
# ID=NFLX_640_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=NFLX_657.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 22
# ID=NFLX_685_2015.06.12_Call, number of spoofing trade = 0, total trades = 29
# ID=CSC_72.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=TSLA_257.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=FB_82_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=TLT_115_2015.06.12_Put, number of spoofing trade = 0, total trades = 6
# ID=FB_82.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=FB_81_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_665_2015.06.12_Call, number of spoofing trade = 0, total trades = 28
# ID=TSLA_252.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 12
# ID=TLT_113.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 7
# ID=AAPL_125_2015.07.17_Put, number of spoofing trade = 1, total trades = 23
# ID=AAPL_120_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=AMZN_430_2015.06.12_Call, number of spoofing trade = 1, total trades = 26
# ID=SPY_201_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=QRVO_80_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_203_2015.06.30_Put, number of spoofing trade = 0, total trades = 10
# ID=NFLX_700_2015.06.19_Call, number of spoofing trade = 6, total trades = 110
# ID=SPY_204_2015.06.30_Put, number of spoofing trade = 0, total trades = 7
# ID=JD_37_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=EFA_64_2015.07.24_Put, number of spoofing trade = 0, total trades = 4
# ID=AMZN_420_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_208_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=NFLX_680_2015.06.19_Call, number of spoofing trade = 0, total trades = 103
# ID=BRCM_49_2015.06.19_Call, number of spoofing trade = 0, total trades = 10
# ID=SPY_200_2015.07.17_Put, number of spoofing trade = 1, total trades = 4
# ID=SWKS_110_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_210.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=SWKS_105_2015.07.17_Call, number of spoofing trade = 1, total trades = 5
# ID=TWTR_36_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=PCLN_1175_2015.06.12_Call, number of spoofing trade = 0, total trades = 13
# ID=GS_212.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=GOOG_530_2015.06.12_Call, number of spoofing trade = 0, total trades = 18
# ID=WETF_22_2015.07.17_Put, number of spoofing trade = 1, total trades = 106
# ID=TWTR_36_2015.06.12_Call, number of spoofing trade = 2, total trades = 5
# ID=AMZN_427.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=LC_12_2016.01.15_Put, number of spoofing trade = 0, total trades = 14
# ID=NFLX_642.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=TSLA_235_2015.06.12_Put, number of spoofing trade = 0, total trades = 13
# ID=TWTR_40_2015.09.18_Call, number of spoofing trade = 2, total trades = 8
# ID=ESPR_100_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=QQQ_112_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=MNKD_7_2015.11.20_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_652.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 25
# ID=NFLX_615_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=IWM_125.5_2015.06.12_Put, number of spoofing trade = 2, total trades = 17
# ID=SPY_209_2015.07.17_Call, number of spoofing trade = 1, total trades = 5
# ID=JCI_57.5_2015.10.16_Call, number of spoofing trade = 0, total trades = 5
# ID=TSLA_240_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=AAL_40.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=AMBA_110_2015.09.18_Put, number of spoofing trade = 0, total trades = 46
# ID=NFLX_672.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 14
# ID=BABA_95_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=GPRO_56_2015.06.12_Put, number of spoofing trade = 0, total trades = 12
# ID=SPY_213_2015.06.30_Call, number of spoofing trade = 0, total trades = 3
# ID=AMZN_425_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=TSLA_242.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 7
# ID=FB_81.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=QQQ_111_2015.06.19_Call, number of spoofing trade = 1, total trades = 8
# ID=IBM_167.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=NFLX_675_2015.06.19_Put, number of spoofing trade = 3, total trades = 41
# ID=PRU_90_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=BABA_88_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=IBM_167.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=TBT_55_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_210_2015.06.12_Put, number of spoofing trade = 0, total trades = 12
# ID=TSLA_275_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=AMZN_440_2015.06.19_Call, number of spoofing trade = 1, total trades = 7
# ID=SPY_206_2015.06.30_Put, number of spoofing trade = 0, total trades = 11
# ID=SPY_205_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=AMZN_432.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=P_18_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=FCX_22_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=ACT_297.5_2015.06.19_Put, number of spoofing trade = 1, total trades = 4
# ID=IBM_170_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=WWAV_47.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=EEM_41_2015.09.18_Put, number of spoofing trade = 0, total trades = 3
# ID=LLY_80_2015.06.19_Call, number of spoofing trade = 0, total trades = 22
# ID=NTAP_33.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 35
# ID=PCLN_1170_2015.06.12_Call, number of spoofing trade = 1, total trades = 10
# ID=HRTX_25_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=SPY_211_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=CVX_101_2015.06.12_Put, number of spoofing trade = 0, total trades = 4
# ID=AMGN_160_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=MDAS_20_2015.06.19_Call, number of spoofing trade = 0, total trades = 17
# ID=AXP_80_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=BIDU_202.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 6
# ID=SPY_207_2015.06.30_Put, number of spoofing trade = 0, total trades = 5
# ID=TSLA_252.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 14
# ID=NFLX_605_2015.06.12_Put, number of spoofing trade = 0, total trades = 6
# ID=TSLA_252.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=WMT_75_2015.07.17_Call, number of spoofing trade = 13, total trades = 127
# ID=PCLN_1160_2015.06.12_Put, number of spoofing trade = 0, total trades = 4
# ID=GS_210_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=AAL_40_2015.06.12_Call, number of spoofing trade = 1, total trades = 4
# ID=AAPL_125_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=VXX_19_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=BRK/B_115_2017.01.20_Put, number of spoofing trade = 0, total trades = 8
# ID=NFLX_627.5_2015.06.12_Put, number of spoofing trade = 2, total trades = 7
# ID=SRPT_20_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=QQQ_107_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_637.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 6
# ID=EOG_90.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_650_2015.06.19_Put, number of spoofing trade = 1, total trades = 20
# ID=IYR_75_2015.06.19_Call, number of spoofing trade = 1, total trades = 7
# ID=GPRO_57.5_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=AAPL_127_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=NFLX_662.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 19
# ID=NFLX_590_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=GOOGL_557.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 10
# ID=AAPL_122_2015.06.19_Put, number of spoofing trade = 0, total trades = 10
# ID=XOM_87.5_2015.10.16_Call, number of spoofing trade = 0, total trades = 3
# ID=JCI_52.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=VXX_18.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 3
# ID=SPY_215_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=SCTY_56.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_720_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=LULU_68_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=DAL_43_2015.06.19_Call, number of spoofing trade = 0, total trades = 21
# ID=NFLX_642.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=PCLN_1100_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=BABA_88_2015.06.12_Call, number of spoofing trade = 0, total trades = 23
# ID=AGU_97.5_2015.07.17_Put, number of spoofing trade = 0, total trades = 6
# ID=AMZN_422.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=QQQ_108.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=ATVI_25.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=AMZN_430_2015.06.19_Call, number of spoofing trade = 2, total trades = 29
# ID=GOOG_527.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=PCLN_1165_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_620_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_700_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=UAL_55_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=TSLA_262.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=XOP_50.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 42
# ID=WFM_40_2015.06.19_Call, number of spoofing trade = 1, total trades = 7
# ID=AAPL_130_2015.06.26_Call, number of spoofing trade = 0, total trades = 13
# ID=GOOGL_570_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=TSLA_235_2015.07.17_Put, number of spoofing trade = 1, total trades = 10
# ID=TLT_115_2015.07.02_Put, number of spoofing trade = 0, total trades = 7
# ID=GOOG_525_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=GILD_119_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=EGN_75_2015.07.17_Call, number of spoofing trade = 0, total trades = 13
# ID=EBAY_70_2015.10.16_Call, number of spoofing trade = 1, total trades = 3
# ID=TWTR_36_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=IWM_121_2015.07.17_Put, number of spoofing trade = 0, total trades = 10
# ID=NFLX_617.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 7
# ID=SPY_211_2015.06.19_Put, number of spoofing trade = 1, total trades = 6
# ID=SPY_211_2015.06.30_Call, number of spoofing trade = 1, total trades = 12
# ID=IWM_123_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_632.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=IWM_124_2015.06.19_Call, number of spoofing trade = 0, total trades = 15
# ID=MU_25.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 17
# ID=SXC_15_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=PSA_195_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=FB_85_2015.07.17_Call, number of spoofing trade = 0, total trades = 10
# ID=NFLX_655_2015.06.19_Put, number of spoofing trade = 1, total trades = 49
# ID=SRPT_30_2016.01.15_Call, number of spoofing trade = 0, total trades = 17
# ID=IYR_74_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=BIDU_200_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=ONVO_3.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 10
# ID=PRU_85_2015.06.19_Call, number of spoofing trade = 1, total trades = 5
# ID=AAL_39_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=GILD_85_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=AAPL_126_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=GOOG_535_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=SPY_211.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 4
# ID=SWKS_101_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_207_2015.07.17_Put, number of spoofing trade = 1, total trades = 9
# ID=EFA_67_2015.07.02_Call, number of spoofing trade = 0, total trades = 72
# ID=WFM_40_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=FB_82_2015.06.12_Put, number of spoofing trade = 0, total trades = 4
# ID=GS_210_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=MFRM_55_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_682.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 18
# ID=AAPL_110_2015.08.21_Put, number of spoofing trade = 0, total trades = 3
# ID=PCLN_1160_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=BIDU_205_2015.06.12_Put, number of spoofing trade = 1, total trades = 6
# ID=GOOGL_555_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=GOOGL_555_2015.06.19_Call, number of spoofing trade = 1, total trades = 4
# ID=NFLX_675_2015.06.12_Call, number of spoofing trade = 0, total trades = 47
# ID=QQQ_108_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_213_2015.08.21_Call, number of spoofing trade = 0, total trades = 3
# ID=GPRO_57.5_2015.06.12_Put, number of spoofing trade = 4, total trades = 44
# ID=PCLN_1185_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=UVXY_40_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=TSLA_245_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_211_2015.07.17_Call, number of spoofing trade = 2, total trades = 7
# ID=GOOG_527.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=GM_34.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 5
# ID=NFLX_660_2015.06.19_Put, number of spoofing trade = 1, total trades = 87
# ID=GILD_100_2016.01.15_Call, number of spoofing trade = 0, total trades = 4
# ID=AAPL_130_2015.07.24_Call, number of spoofing trade = 0, total trades = 4
# ID=NWBO_7_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=ATVI_25.5_2015.06.12_Call, number of spoofing trade = 3, total trades = 9
# ID=HRTX_30_2015.06.19_Call, number of spoofing trade = 0, total trades = 26
# ID=UVXY_43_2015.06.12_Put, number of spoofing trade = 1, total trades = 11
# ID=URBN_36_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=AMGN_152.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=SPY_211_2015.06.12_Put, number of spoofing trade = 1, total trades = 6
# ID=NFLX_635_2015.06.12_Call, number of spoofing trade = 0, total trades = 11
# ID=IWM_126_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=ANF_24.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_120_2015.08.21_Put, number of spoofing trade = 2, total trades = 4
# ID=CL_67.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=LLY_80_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_660_2015.06.12_Put, number of spoofing trade = 0, total trades = 30
# ID=JMEI_30_2015.10.16_Call, number of spoofing trade = 1, total trades = 26
# ID=GOOG_545_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_680_2015.06.12_Call, number of spoofing trade = 2, total trades = 64
# ID=HLT_29_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=GOOGL_570_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=TSLA_245_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=NFLX_720_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=OXM_85_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_645_2015.06.19_Put, number of spoofing trade = 1, total trades = 12
# ID=NFLX_625_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=SPY_205_2015.06.30_Put, number of spoofing trade = 1, total trades = 4
# ID=AMZN_420_2015.06.12_Put, number of spoofing trade = 0, total trades = 8
# ID=BABA_85_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=AMBA_100_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=SPY_206_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_622.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_700_2015.06.12_Call, number of spoofing trade = 0, total trades = 101
# ID=VXX_18_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_647.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=AAPL_150_2016.01.15_Call, number of spoofing trade = 0, total trades = 10
# ID=AAPL_135_2015.07.17_Call, number of spoofing trade = 0, total trades = 19
# ID=EBAY_55_2015.08.21_Call, number of spoofing trade = 0, total trades = 4
# ID=GPRO_60_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=TBT_51_2015.09.18_Call, number of spoofing trade = 1, total trades = 3
# ID=GOOGL_575_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=BABA_87_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=SWKS_103_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=AAPL_120_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_130_2016.01.15_Put, number of spoofing trade = 0, total trades = 3
# ID=XBI_240_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=LNKD_220_2015.07.17_Call, number of spoofing trade = 0, total trades = 12
# ID=GOOG_540_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=EFA_66_2015.07.17_Call, number of spoofing trade = 0, total trades = 15
# ID=NFLX_620_2015.06.19_Put, number of spoofing trade = 0, total trades = 11
# ID=IBM_170_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=GPRO_58_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_670_2015.06.26_Call, number of spoofing trade = 1, total trades = 4
# ID=IWM_124_2015.08.21_Put, number of spoofing trade = 1, total trades = 4
# ID=AAPL_129_2015.06.26_Put, number of spoofing trade = 0, total trades = 3
# ID=AAPL_115_2015.08.21_Put, number of spoofing trade = 0, total trades = 8
# ID=WMT_72.5_2015.07.17_Call, number of spoofing trade = 2, total trades = 3
# ID=GOOGL_547.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 14
# ID=ISSI_20_2015.10.16_Call, number of spoofing trade = 0, total trades = 8
# ID=BABA_90_2015.06.12_Call, number of spoofing trade = 0, total trades = 19
# ID=VDSI_30_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=GILD_114_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=BABA_85_2016.01.15_Call, number of spoofing trade = 0, total trades = 6
# ID=AAPL_170_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=GILD_115_2015.07.17_Call, number of spoofing trade = 0, total trades = 9
# ID=GOOGL_550_2015.06.12_Put, number of spoofing trade = 1, total trades = 4
# ID=FXI_48.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=FXI_47_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_715_2015.06.19_Call, number of spoofing trade = 0, total trades = 80
# ID=TLT_112_2016.01.15_Put, number of spoofing trade = 0, total trades = 3
# ID=LNKD_215_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=MMM_155_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=SWKS_100_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=ESPR_90_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=TWTR_36_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=BABA_87.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 13
# ID=NTES_160_2015.09.18_Call, number of spoofing trade = 0, total trades = 4
# ID=UAL_52_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=UAL_57_2015.06.19_Call, number of spoofing trade = 0, total trades = 33
# ID=NFLX_665_2015.06.12_Put, number of spoofing trade = 5, total trades = 104
# ID=IWM_124_2015.06.19_Put, number of spoofing trade = 0, total trades = 9
# ID=SPY_209_2015.07.02_Put, number of spoofing trade = 0, total trades = 3
# ID=WY_31_2015.06.26_Call, number of spoofing trade = 0, total trades = 4
# ID=TBT_51_2015.06.26_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_650_2015.06.26_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_690_2015.06.19_Call, number of spoofing trade = 0, total trades = 125
# ID=NFLX_725_2015.07.17_Call, number of spoofing trade = 0, total trades = 10
# ID=NFLX_657.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 6
# ID=IBB_370_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_692.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 48
# ID=TWTR_37_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=TCBI_55_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=NFLX_687.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 13
# ID=SPY_200_2015.09.18_Put, number of spoofing trade = 0, total trades = 6
# ID=BIDU_205_2015.06.12_Call, number of spoofing trade = 5, total trades = 15
# ID=IWM_120_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=FB_77.5_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=AMZN_420_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=NFLX_800_2015.08.21_Call, number of spoofing trade = 0, total trades = 3
# ID=LNKD_220_2015.06.12_Call, number of spoofing trade = 0, total trades = 7
# ID=GOOGL_540_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=MNKD_3_2015.08.21_Call, number of spoofing trade = 0, total trades = 12
# ID=NFLX_640_2015.07.17_Put, number of spoofing trade = 1, total trades = 18
# ID=NFLX_710_2015.06.12_Call, number of spoofing trade = 0, total trades = 42
# ID=AAPL_126_2015.06.26_Put, number of spoofing trade = 1, total trades = 15
# ID=NFLX_680_2015.06.12_Put, number of spoofing trade = 3, total trades = 80
# ID=EBAY_61_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=PCLN_1230_2015.07.17_Call, number of spoofing trade = 5, total trades = 10
# ID=BAC_17_2016.01.15_Call, number of spoofing trade = 0, total trades = 8
# ID=LNKD_217.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 14
# ID=GOOGL_560_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=IWM_125_2015.08.21_Put, number of spoofing trade = 3, total trades = 6
# ID=GOOG_535_2015.06.12_Call, number of spoofing trade = 2, total trades = 20
# ID=MDY_270_2015.07.17_Put, number of spoofing trade = 0, total trades = 13
# ID=GLD_114_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=SPY_205_2015.06.26_Put, number of spoofing trade = 1, total trades = 3
# ID=JPM_67.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=FB_82.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=GILD_117_2015.06.19_Call, number of spoofing trade = 1, total trades = 3
# ID=DIS_95_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=BAC_20_2016.01.15_Call, number of spoofing trade = 0, total trades = 9
# ID=VXX_18.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 11
# ID=NFLX_635_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=SPY_209.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=NFLX_630_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=AMZN_450_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_662.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 7
# ID=NFLX_690_2015.06.12_Call, number of spoofing trade = 14, total trades = 151
# ID=NFLX_682.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=GOOGL_552.5_2015.06.12_Call, number of spoofing trade = 1, total trades = 6
# ID=GILD_116_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=HRTX_27.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=WMT_73_2015.06.19_Call, number of spoofing trade = 1, total trades = 34
# ID=NFLX_670_2015.06.12_Put, number of spoofing trade = 3, total trades = 107
# ID=VXX_18.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 14
# ID=NFLX_670_2015.06.19_Put, number of spoofing trade = 0, total trades = 73
# ID=SPY_187_2015.08.21_Put, number of spoofing trade = 0, total trades = 4
# ID=BABA_88_2015.06.19_Call, number of spoofing trade = 0, total trades = 20
# ID=BABA_89_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=VXX_20.5_2015.06.26_Put, number of spoofing trade = 0, total trades = 3
# ID=LNKD_222.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 8
# ID=NFLX_680_2015.07.10_Call, number of spoofing trade = 0, total trades = 3
# ID=GOOG_525_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=XLB_52_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_685_2015.06.19_Call, number of spoofing trade = 0, total trades = 33
# ID=GOOGL_552.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=V_65_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=FAS_32.75_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=BIIB_385_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=VMI_120_2015.12.18_Put, number of spoofing trade = 0, total trades = 4
# ID=AAPL_129_2015.07.02_Call, number of spoofing trade = 0, total trades = 3
# ID=UAL_56_2015.06.19_Call, number of spoofing trade = 1, total trades = 26
# ID=MSFT_35_2016.01.15_Put, number of spoofing trade = 0, total trades = 3
# ID=RH_95_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=NFLX_617.5_2015.06.19_Put, number of spoofing trade = 2, total trades = 3
# ID=IMMU_5_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=GOOG_532.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=NFLX_600_2015.06.12_Put, number of spoofing trade = 0, total trades = 9
# ID=MW_62.5_2015.07.17_Call, number of spoofing trade = 1, total trades = 8
# ID=LNKD_220_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=UNH_120_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=AMZN_442.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=WMB_52_2015.07.10_Put, number of spoofing trade = 1, total trades = 4
# ID=JCI_55_2015.06.19_Call, number of spoofing trade = 1, total trades = 10
# ID=TSLA_250_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=FB_85_2015.08.21_Call, number of spoofing trade = 0, total trades = 5
# ID=LNKD_240_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=C_55_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=DAL_42_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_740_2015.07.17_Call, number of spoofing trade = 0, total trades = 12
# ID=AAL_39_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=EFA_68.5_2015.06.26_Call, number of spoofing trade = 0, total trades = 7
# ID=TSLA_245_2015.07.17_Call, number of spoofing trade = 4, total trades = 5
# ID=CRZO_47.5_2015.07.17_Put, number of spoofing trade = 1, total trades = 3
# ID=TLT_120_2015.06.19_Call, number of spoofing trade = 1, total trades = 9
# ID=TLT_100_2016.01.15_Put, number of spoofing trade = 0, total trades = 5
# ID=NFLX_697.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 9
# ID=TSLA_232.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=TSLA_262.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=UVXY_40_2015.06.12_Put, number of spoofing trade = 0, total trades = 7
# ID=QQQ_110_2015.07.17_Put, number of spoofing trade = 1, total trades = 5
# ID=AIG_60_2015.07.17_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_450_2015.08.21_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_675_2015.06.19_Call, number of spoofing trade = 0, total trades = 10
# ID=ILMN_217.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 7
# ID=BIDU_200_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=FB_82.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=FB_83_2015.06.19_Put, number of spoofing trade = 1, total trades = 7
# ID=FB_80_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=TXT_46_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=LNKD_222.5_2015.06.19_Call, number of spoofing trade = 1, total trades = 7
# ID=AAPL_115_2016.01.15_Put, number of spoofing trade = 0, total trades = 3
# ID=LNKD_210_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=AMZN_432.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=AAPL_131_2015.06.12_Put, number of spoofing trade = 0, total trades = 20
# ID=UVXY_39.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=GOOG_540_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=PCLN_1162.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=LUV_36_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=LNKD_220_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=ALXN_155_2015.06.19_Put, number of spoofing trade = 2, total trades = 3
# ID=GS_205_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NFLX_565_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=NFLX_682.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 57
# ID=MYL_75_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=DIA_180_2015.07.17_Call, number of spoofing trade = 0, total trades = 17
# ID=DAL_41_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=FAS_32.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 9
# ID=QQQ_110_2015.09.18_Put, number of spoofing trade = 0, total trades = 8
# ID=CELG_112_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=LULU_67_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=VALE_8_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ...
# ID=AMZN_500_2016.01.15_Call, number of spoofing trade = 0, total trades = 22
# ID=MW_62.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=DEO_120_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=PCLN_1255_2015.07.17_Call, number of spoofing trade = 5, total trades = 12
# ID=TCBI_65_2015.09.18_Call, number of spoofing trade = 0, total trades = 4
# ID=ALSN_30_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=BIDU_160_2017.01.20_Put, number of spoofing trade = 0, total trades = 8
# ID=MNKD_4_2015.08.21_Call, number of spoofing trade = 0, total trades = 7
# ID=LNG_70_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=FSLR_52_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=SCTY_60_2016.01.15_Call, number of spoofing trade = 0, total trades = 5
# ID=ECL_110_2015.07.17_Put, number of spoofing trade = 0, total trades = 10
# ID=TNA_86_2015.06.19_Put, number of spoofing trade = 1, total trades = 3
# ID=GILD_100_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=QQQ_120_2017.01.20_Call, number of spoofing trade = 0, total trades = 3
# ID=HAL_48_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=PXD_155_2015.06.19_Call, number of spoofing trade = 1, total trades = 4
# ID=NFLX_765_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=XRT_96_2015.09.18_Call, number of spoofing trade = 0, total trades = 4
# ID=KBE_35_2015.12.18_Call, number of spoofing trade = 1, total trades = 5
# ID=MKTO_30_2015.06.19_Put, number of spoofing trade = 1, total trades = 9
# ID=COF_86.5_2015.06.19_Put, number of spoofing trade = 1, total trades = 4
# ID=NDX_4750_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=KRE_36_2016.01.15_Call, number of spoofing trade = 0, total trades = 5
# ID=TYC_40_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=UNP_130_2016.01.15_Call, number of spoofing trade = 0, total trades = 8
# ID=TSO_84.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 4
# ID=DRI_62.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=DFS_60_2015.10.16_Call, number of spoofing trade = 0, total trades = 3
# ID=AXP_85_2015.08.21_Put, number of spoofing trade = 0, total trades = 4
# ID=LYB_110_2015.09.18_Call, number of spoofing trade = 0, total trades = 4
# ID=RAI_77.5_2016.01.15_Put, number of spoofing trade = 0, total trades = 4
# ID=GPS_36_2016.01.15_Put, number of spoofing trade = 0, total trades = 5
# ID=ACT_302.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 3
# ID=CTRX_60_2015.07.17_Put, number of spoofing trade = 0, total trades = 9
# ID=AAPL_118_2015.07.10_Call, number of spoofing trade = 0, total trades = 4
# ID=SPWR_32.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=TLT_120_2015.06.26_Call, number of spoofing trade = 0, total trades = 6
# ID=LNKD_220_2015.06.12_Put, number of spoofing trade = 0, total trades = 5
# ID=GOOGL_552.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=FSLR_51.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=SPWR_31_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=NEM_23_2015.08.21_Put, number of spoofing trade = 1, total trades = 11
# ID=PG_82.5_2015.10.16_Put, number of spoofing trade = 0, total trades = 5
# ID=SBUX_55_2015.08.21_Call, number of spoofing trade = 1, total trades = 3
# ID=UAL_51_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=DLR_65_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=EFA_67_2015.06.19_Call, number of spoofing trade = 1, total trades = 41
# ID=AAPL_122_2015.06.26_Call, number of spoofing trade = 0, total trades = 3
# ID=TASR_26_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=AON_95_2015.07.17_Put, number of spoofing trade = 0, total trades = 6
# ID=CELG_108_2015.07.10_Put, number of spoofing trade = 0, total trades = 5
# ID=V_68.75_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=AXP_75_2015.10.16_Call, number of spoofing trade = 0, total trades = 4
# ID=FB_85_2015.09.18_Put, number of spoofing trade = 0, total trades = 7
# ID=AMT_93_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=ENDP_85_2015.06.19_Call, number of spoofing trade = 0, total trades = 27
# ID=SWK_105_2017.01.20_Call, number of spoofing trade = 0, total trades = 5
# ID=HYG_85_2015.09.18_Put, number of spoofing trade = 0, total trades = 6
# ID=TLT_115_2015.06.26_Put, number of spoofing trade = 0, total trades = 3
# ID=C_46.5_2015.06.26_Put, number of spoofing trade = 0, total trades = 4
# ID=ISIS_64.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=PM_83_2015.07.24_Call, number of spoofing trade = 0, total trades = 20
# ID=TLT_115.5_2015.06.26_Put, number of spoofing trade = 0, total trades = 5
# ID=TLT_115.5_2015.06.26_Call, number of spoofing trade = 0, total trades = 5
# ID=TLT_115.5_2015.07.02_Call, number of spoofing trade = 0, total trades = 4
# ID=NFLX_565_2015.09.18_Put, number of spoofing trade = 5, total trades = 5
# ID=PCLN_1215_2015.06.12_Call, number of spoofing trade = 1, total trades = 10
# ID=RH_95_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=IYR_80_2016.01.15_Call, number of spoofing trade = 0, total trades = 7
# ID=AMAT_20_2017.01.20_Put, number of spoofing trade = 0, total trades = 21
# ID=FB_80_2015.08.21_Put, number of spoofing trade = 0, total trades = 12
# ID=MET_56.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=LNKD_235_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=WMGI_25_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=ABMD_70_2015.06.19_Call, number of spoofing trade = 0, total trades = 8
# ID=NKE_110_2015.07.17_Call, number of spoofing trade = 0, total trades = 13
# ID=PCLN_1117.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=YELP_45_2015.06.12_Put, number of spoofing trade = 0, total trades = 5
# ID=CLH_60_2015.07.17_Call, number of spoofing trade = 0, total trades = 11
# ID=FB_75_2015.10.16_Put, number of spoofing trade = 0, total trades = 3
# ID=WDAY_79_2015.06.19_Call, number of spoofing trade = 0, total trades = 18
# ID=AMZN_392.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 7
# ID=XLY_79_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=CRM_73_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=XLY_77_2016.01.15_Put, number of spoofing trade = 0, total trades = 5
# ID=TNA_49.52_2016.01.15_Put, number of spoofing trade = 0, total trades = 4
# ID=AIG_58.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 7
# ID=IYR_78_2015.09.18_Call, number of spoofing trade = 0, total trades = 13
# ID=PGNX_7_2015.07.17_Call, number of spoofing trade = 1, total trades = 7
# ID=TLT_124_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=GEVA_140_2015.06.19_Put, number of spoofing trade = 0, total trades = 9
# ID=ZOES_40_2015.07.17_Put, number of spoofing trade = 0, total trades = 102
# ID=BIDU_207.5_2015.07.10_Call, number of spoofing trade = 0, total trades = 4
# ID=AMZN_440_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=VLO_65_2015.12.18_Call, number of spoofing trade = 1, total trades = 4
# ID=VALE_6_2016.01.15_Call, number of spoofing trade = 0, total trades = 4
# ID=MBFI_35_2015.08.21_Call, number of spoofing trade = 1, total trades = 5
# ID=ATW_30_2015.07.17_Put, number of spoofing trade = 1, total trades = 10
# ID=IYR_73_2015.07.02_Put, number of spoofing trade = 0, total trades = 5
# ID=GILD_125_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=MDXG_12.5_2015.12.18_Call, number of spoofing trade = 0, total trades = 5
# ID=FAS_33.5_2015.06.12_Put, number of spoofing trade = 0, total trades = 3
# ID=C_45.5_2015.06.26_Put, number of spoofing trade = 0, total trades = 11
# ID=BIIB_370_2015.07.17_Put, number of spoofing trade = 0, total trades = 14
# ID=NWBO_8_2015.06.19_Call, number of spoofing trade = 0, total trades = 6
# ID=UNP_101_2015.06.19_Call, number of spoofing trade = 1, total trades = 17
# ID=YELP_45_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=CMG_570_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=DLR_65_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=IBM_172.5_2015.07.02_Put, number of spoofing trade = 0, total trades = 20
# ID=HYG_89_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=DIA_176_2015.09.18_Call, number of spoofing trade = 0, total trades = 6
# ID=ZOES_40_2015.06.19_Call, number of spoofing trade = 0, total trades = 11
# ID=VC_110_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=INO_9_2015.06.19_Call, number of spoofing trade = 0, total trades = 3
# ID=BIDU_202.5_2015.07.02_Put, number of spoofing trade = 0, total trades = 7
# ID=AAL_43.5_2015.07.24_Call, number of spoofing trade = 0, total trades = 4
# ID=BJRI_50_2015.10.16_Call, number of spoofing trade = 1, total trades = 13
# ID=SPW_85_2015.12.18_Call, number of spoofing trade = 0, total trades = 8
# ID=BWLD_155_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=BAX_72.5_2016.01.15_Call, number of spoofing trade = 1, total trades = 4
# ID=AMBA_110_2015.09.18_Call, number of spoofing trade = 0, total trades = 47
# ID=CCIH_17.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 5
# ID=BABA_70_2015.09.18_Put, number of spoofing trade = 1, total trades = 5
# ID=GOOGL_490_2016.01.15_Put, number of spoofing trade = 0, total trades = 3
# ID=BWLD_160_2015.06.19_Call, number of spoofing trade = 1, total trades = 6
# ID=V_67_2015.06.12_Put, number of spoofing trade = 0, total trades = 4
# ID=EFA_67_2015.06.12_Call, number of spoofing trade = 0, total trades = 6
# ID=EDU_26_2015.06.19_Call, number of spoofing trade = 0, total trades = 7
# ID=KMT_35_2015.06.19_Put, number of spoofing trade = 0, total trades = 9
# ID=EOG_100_2015.07.02_Call, number of spoofing trade = 0, total trades = 80
# ID=ADI_75_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=EFA_65_2016.01.15_Call, number of spoofing trade = 0, total trades = 5
# ID=WFM_52.5_2015.11.20_Call, number of spoofing trade = 0, total trades = 3
# ID=BBRY_10_2015.09.18_Call, number of spoofing trade = 0, total trades = 3
# ID=ARLP_25_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=EQR_60_2015.10.16_Put, number of spoofing trade = 0, total trades = 20
# ID=BIIB_395_2015.06.12_Call, number of spoofing trade = 0, total trades = 15
# ID=EQR_70_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=HRB_35_2015.07.17_Call, number of spoofing trade = 0, total trades = 18
# ID=CYBR_70_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=DECK_85_2015.08.21_Call, number of spoofing trade = 0, total trades = 4
# ID=GOOG_515_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=RL_145_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=DIA_186_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=DANG_12_2016.01.15_Call, number of spoofing trade = 0, total trades = 3
# ID=YELP_48.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 10
# ID=NTRI_22_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=VZ_48_2015.08.21_Call, number of spoofing trade = 2, total trades = 7
# ID=BA_150_2017.01.20_Put, number of spoofing trade = 0, total trades = 3
# ID=WFT_15_2016.01.15_Call, number of spoofing trade = 0, total trades = 23
# ID=AXTA_30_2015.07.17_Put, number of spoofing trade = 0, total trades = 6
# ID=RNWK_7.5_2015.08.21_Call, number of spoofing trade = 0, total trades = 6
# ID=XOP_49_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=GPC_95_2015.11.20_Call, number of spoofing trade = 0, total trades = 12
# ID=PM_85_2015.06.19_Call, number of spoofing trade = 0, total trades = 5
# ID=HD_111_2015.07.24_Call, number of spoofing trade = 0, total trades = 3
# ID=PRLB_65_2015.07.17_Put, number of spoofing trade = 0, total trades = 4
# ID=XLK_44_2016.01.15_Call, number of spoofing trade = 0, total trades = 9
# ID=ETFC_31.5_2015.06.12_Call, number of spoofing trade = 0, total trades = 5
# ID=XLK_42_2016.01.15_Put, number of spoofing trade = 0, total trades = 4
# ID=KRE_44_2015.07.17_Put, number of spoofing trade = 0, total trades = 11
# ID=JMEI_20_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=KANG_25_2015.07.17_Call, number of spoofing trade = 0, total trades = 7
# ID=BOX_20_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=CMGE_20_2015.12.18_Call, number of spoofing trade = 0, total trades = 11
# ID=RKUS_12.5_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=IBM_165_2017.01.20_Put, number of spoofing trade = 0, total trades = 3
# ID=TSLA_95_2015.09.18_Put, number of spoofing trade = 0, total trades = 3
# ID=VALE_8_2015.07.17_Call, number of spoofing trade = 0, total trades = 8
# ID=PANW_167.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 3
# ID=VALE_7_2015.07.02_Call, number of spoofing trade = 0, total trades = 11
# ID=EXP_80_2015.07.17_Put, number of spoofing trade = 0, total trades = 3
# ID=MO_49.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 8
# ID=TSLA_225_2015.07.24_Put, number of spoofing trade = 0, total trades = 8
# ID=PM_83.5_2015.07.24_Call, number of spoofing trade = 0, total trades = 4
# ID=SWKS_113_2015.07.24_Call, number of spoofing trade = 0, total trades = 5
# ID=JMEI_40_2017.01.20_Call, number of spoofing trade = 0, total trades = 3
# ID=ANIK_40_2015.07.17_Call, number of spoofing trade = 1, total trades = 8
# ID=TWTR_40_2015.09.18_Put, number of spoofing trade = 0, total trades = 4
# ID=UTX_120_2015.07.24_Call, number of spoofing trade = 0, total trades = 22
# ID=PANW_187.5_2015.07.24_Call, number of spoofing trade = 0, total trades = 4
# ID=SBUX_57.5_2015.10.16_Call, number of spoofing trade = 0, total trades = 4
# ID=EEM_41_2015.07.17_Put, number of spoofing trade = 0, total trades = 5
# ID=MTG_10_2015.06.19_Call, number of spoofing trade = 0, total trades = 4
# ID=CBS_59.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=DVY_78_2015.07.17_Call, number of spoofing trade = 0, total trades = 4
# ID=IWM_125_2016.03.18_Put, number of spoofing trade = 0, total trades = 3
# ID=UNP_110_2015.07.24_Call, number of spoofing trade = 0, total trades = 5
# ID=ITB_26_2015.07.02_Call, number of spoofing trade = 0, total trades = 9
# ID=UVXY_30_2015.12.18_Put, number of spoofing trade = 1, total trades = 3
# ID=WMT_70.5_2015.07.24_Call, number of spoofing trade = 0, total trades = 13
# ID=REMX_25_2015.11.20_Put, number of spoofing trade = 0, total trades = 3
# ID=ARRS_35_2015.08.21_Call, number of spoofing trade = 0, total trades = 3
# ID=GLW_21.5_2015.06.19_Put, number of spoofing trade = 0, total trades = 4
# ID=GOOG_532.5_2015.07.02_Put, number of spoofing trade = 0, total trades = 6
# ID=AAL_65_2017.01.20_Call, number of spoofing trade = 0, total trades = 6
# ID=ABC_105_2015.06.19_Put, number of spoofing trade = 0, total trades = 5
# ID=FB_82.5_2015.10.16_Put, number of spoofing trade = 0, total trades = 5
# ID=ONVO_3.5_2016.01.15_Call, number of spoofing trade = 0, total trades = 10
# ID=OVTI_27_2015.07.17_Call, number of spoofing trade = 0, total trades = 6
# ID=KEYW_10_2015.11.20_Put, number of spoofing trade = 0, total trades = 8
# ID=JCP_8.5_2015.06.19_Call, number of spoofing trade = 0, total trades = 102
# ID=PRU_75_2017.01.20_Put, number of spoofing trade = 0, total trades = 5
# ID=FCAU_14_2016.01.15_Put, number of spoofing trade = 0, total trades = 20
# ID=AIG_62.5_2015.08.21_Put, number of spoofing trade = 1, total trades = 9
# ID=TWTR_35_2015.07.10_Put, number of spoofing trade = 0, total trades = 3
# ID=BC_55_2015.09.18_Call, number of spoofing trade = 0, total trades = 6
# ID=CONN_35_2015.07.17_Put, number of spoofing trade = 0, total trades = 10
# ID=SCTY_60_2017.01.20_Call, number of spoofing trade = 0, total trades = 5
# ID=EEM_38.5_2015.07.02_Put, number of spoofing trade = 0, total trades = 3
# ID=XRT_98_2015.06.26_Put, number of spoofing trade = 0, total trades = 12
# total finding =353
# total trades = 12408

# %%
df = pd.read_csv('OrderSummary.csv')

# %%
df.columns
# Out:
# Index([u'date', u'orderid', u'id', u'order_time', u'side', u'symbol',
#        u'account', u'order_shares', u'orderstatus', u'tif', u'exec_shares',
#        u'exec_last_time', u'explicit_cxl_time', u'fill_rate', u'auto_cxl_time',
#        u'cxl_time', u'hidden'],
#       dtype='object')

# %%
df['symbol'].unique().size
# Out:
# 52408

# %%
df1['symbol'].unique().size
# Out:
# 6051

# %%
df.size
# Out:
# 99250677

# %%
df['mtype'].value_counts()
# Out:
# NewOrder             932763
# OrderCancelled       916133
# CancelRequest        903731
# NewOrderConfirmed    902706
# Filled                15245
# PartialFill            3801
# OrderRejected          1413
# CancelReject            159
# Name: mtype, dtype: int64

# %%
df = pd.read_csv('OrderSummary.csv')

# %%
df.head(5)
# Out:
#                       date     orderid         id               order_time  \
# 0  2013-01-02 00:00:00.000  4605204951  KFERGUSON  1900-01-01 07:00:58.126
# 1  2013-01-02 00:00:00.000  4605204952  KFERGUSON  1900-01-01 07:01:04.696
# 2  2013-01-02 00:00:00.000  4605204955     arizer  1900-01-01 07:01:42.863
# 3  2013-01-02 00:00:00.000  4605204958     arizer  1900-01-01 07:01:46.975
# 4  2013-01-02 00:00:00.000  4605204961  KFERGUSON  1900-01-01 07:01:48.628
#
#   side symbol   account  order_shares orderstatus  tif  exec_shares  \
# 0    S   DELL  5AO05128          1000      UR OUT  DAY          0.0
# 1    S   DELL  5AO05128          1000      UR OUT  DAY          0.0
# 2    S    MCP  5AO05134           850      UR OUT  DAY        100.0
# 3    S    MCP  5AO05134           650      UR OUT  DAY        500.0
# 4    S   VISN  5AO05128          2400      UR OUT  DAY          0.0
#
#             exec_last_time        explicit_cxl_time  fill_rate auto_cxl_time  \
# 0                      NaN  1900-01-01 07:32:22.130   0.000000           NaN
# 1                      NaN  1900-01-01 07:28:24.261   0.000000           NaN
# 2  1900-01-01 07:01:42.870  1900-01-01 07:01:45.190   0.117647           NaN
# 3  1900-01-01 07:02:06.000  1900-01-01 07:02:22.848   0.769231           NaN
# 4                      NaN  1900-01-01 08:04:11.023   0.000000           NaN
#
#                   cxl_time hidden
# 0  1900-01-01 07:32:22.130  False
# 1  1900-01-01 07:28:24.261  False
# 2  1900-01-01 07:01:45.190  False
# 3  1900-01-01 07:02:22.848  False
# 4  1900-01-01 08:04:11.023  False

# %%
df[df['fill_rate']>0]
# Out:
#                              date     orderid         id  \
# 2         2013-01-02 00:00:00.000  4605204955     arizer
# 3         2013-01-02 00:00:00.000  4605204958     arizer
# 6         2013-01-02 00:00:00.000  4605204972     arizer
# 8         2013-01-02 00:00:00.000  4605204976     arizer
# 9         2013-01-02 00:00:00.000  4605204977     arizer
# 32        2013-01-02 00:00:00.000  4605205045     arizer
# 42        2013-01-02 00:00:00.000  4605205088     arizer
# 44        2013-01-02 00:00:00.000  4605205093     arizer
# 45        2013-01-02 00:00:00.000  4605205112     arizer
# 49        2013-01-02 00:00:00.000  4605205118     arizer
# 51        2013-01-02 00:00:00.000  4605205128     arizer
# 54        2013-01-02 00:00:00.000  4605205137     arizer
# 60        2013-01-02 00:00:00.000  4605205150     arizer
# 61        2013-01-02 00:00:00.000  4605205151     arizer
# 77        2013-01-02 00:00:00.000  4605205319     arizer
# 79        2013-01-02 00:00:00.000  4605205325  KFERGUSON
# 80        2013-01-02 00:00:00.000  4605205326  KFERGUSON
# 138       2013-01-02 00:00:00.000  4605205411  KFERGUSON
# 166       2013-01-02 00:00:00.000  4605205455  KFERGUSON
# 168       2013-01-02 00:00:00.000  4605205458  KFERGUSON
# 169       2013-01-02 00:00:00.000  4605205457  KFERGUSON
# 202       2013-01-02 00:00:00.000  4605205497  KFERGUSON
# 209       2013-01-02 00:00:00.000  4605205509  KFERGUSON
# 210       2013-01-02 00:00:00.000  4605205508  KFERGUSON
# 233       2013-01-02 00:00:00.000  4605205546  KFERGUSON
# 260       2013-01-02 00:00:00.000  4605205587  KFERGUSON
# 313       2013-01-02 00:00:00.000  4605205692  KFERGUSON
# 351       2013-01-02 00:00:00.000  4605205755     arizer
# 352       2013-01-02 00:00:00.000  4605205760     arizer
# 435       2013-01-02 00:00:00.000  4605205894     arizer
# ...                           ...         ...        ...
# 10706321  2016-01-14 00:00:00.000  4740564825     jguber
# 10706366  2016-01-14 00:00:00.000  4740565478   DLAZARUS
# 10706368  2016-01-14 00:00:00.000  4740565539  KFERGUSON
# 10706379  2016-01-14 00:00:00.000  4740565708  KFERGUSON
# 10706400  2016-01-14 00:00:00.000  4740566073     jguber
# 10706405  2016-01-14 00:00:00.000  4740566102     jguber
# 10706408  2016-01-14 00:00:00.000  4740566128     jguber
# 10706434  2016-01-14 00:00:00.000  4740566621  KFERGUSON
# 10706453  2016-01-14 00:00:00.000  4740571298  KFERGUSON
# 10706454  2016-01-14 00:00:00.000  4740571439  KFERGUSON
# 10706456  2016-01-14 00:00:00.000  4740571972  KFERGUSON
# 10706460  2016-01-14 00:00:00.000  4740573605     jguber
# 10706461  2016-01-14 00:00:00.000  4740573610     jguber
# 10706464  2016-01-14 00:00:00.000  4740573621     jguber
# 10706465  2016-01-14 00:00:00.000  4740573623     jguber
# 10706466  2016-01-14 00:00:00.000  4740573825  KFERGUSON
# 10706473  2016-01-14 00:00:00.000  4740574260   DLAZARUS
# 10706478  2016-01-14 00:00:00.000  4740574377  KFERGUSON
# 10706479  2016-01-14 00:00:00.000  4740574459  KFERGUSON
# 10706523  2016-01-14 00:00:00.000  4740575231  KFERGUSON
# 10706528  2016-01-14 00:00:00.000  4740575883     jguber
# 10706539  2016-01-14 00:00:00.000  4740575928     jguber
# 10706541  2016-01-14 00:00:00.000  4740575936     jguber
# 10706542  2016-01-14 00:00:00.000  4740575938     jguber
# 10706548  2016-01-14 00:00:00.000  4740577816  KFERGUSON
# 10706550  2016-01-14 00:00:00.000  4740577819  KFERGUSON
# 10706572  2016-01-14 00:00:00.000  4740578159  KFERGUSON
# 10706581  2016-01-14 00:00:00.000  4740578198  KFERGUSON
# 10706592  2016-01-14 00:00:00.000  4740578310  KFERGUSON
# 10706597  2016-01-14 00:00:00.000  4740578321  KFERGUSON
#
#                        order_time side symbol   account  order_shares  \
# 2         1900-01-01 07:01:42.863    S    MCP  5AO05134           850
# 3         1900-01-01 07:01:46.975    S    MCP  5AO05134           650
# 6         1900-01-01 07:02:15.280    B   EBAY  5AO05134          1135
# 8         1900-01-01 07:02:22.857    S    MCP  5AO05134           150
# 9         1900-01-01 07:02:44.673    S   JDSU  5AO05134          3331
# 32        1900-01-01 07:06:46.972    B    FXI  5AO05134           455
# 42        1900-01-01 07:08:46.022    B   EBAY  5AO05134          1007
# 44        1900-01-01 07:08:58.662    S   LULU  5AO05134           100
# 45        1900-01-01 07:09:18.998    S   GILD  5AO05134           100
# 49        1900-01-01 07:09:49.721    S    ARR  5AO05134           660
# 51        1900-01-01 07:10:39.608    S    DOW  5AO05134           100
# 54        1900-01-01 07:10:55.751    S    WFT  5AO05134           200
# 60        1900-01-01 07:11:17.080    B   NYCB  5AO05134           100
# 61        1900-01-01 07:11:20.808    B     VE  5AO05134           100
# 77        1900-01-01 07:27:45.232    B   EBAY  5AO05134           500
# 79        1900-01-01 07:28:28.136    S   DELL  5AO05128          1000
# 80        1900-01-01 07:28:54.143    S    ABT  5AO05128           500
# 138       1900-01-01 07:32:24.281    S   DELL  5AO05128          1000
# 166       1900-01-01 07:33:31.765    S    ABT  5AO05128           900
# 168       1900-01-01 07:33:31.767    S    ABT  5AO05128           900
# 169       1900-01-01 07:33:31.768    S    ABT  5AO05128           900
# 202       1900-01-01 07:36:12.589    S    ABT  5AO05128           300
# 209       1900-01-01 07:37:01.704    S    LGP  5AO05128          1500
# 210       1900-01-01 07:37:01.705    S    LGP  5AO05128          1500
# 233       1900-01-01 07:39:17.574    S    ABT  5AO05128           500
# 260       1900-01-01 07:41:21.741    B    NOW  5AO05128          1000
# 313       1900-01-01 07:43:44.906    S    ABT  5AO05128          1500
# 351       1900-01-01 07:45:36.418    B    KWK  5AO05134          1000
# 352       1900-01-01 07:45:37.762    B    KWK  5AO05134          1000
# 435       1900-01-01 07:49:20.658    B   EBAY  5AO05134           500
# ...                           ...  ...    ...       ...           ...
# 10706321  1900-01-01 15:58:40.156    B     CB  5AO05043          5000
# 10706366  1900-01-01 15:59:22.025    B     CB  5AO05129          2000
# 10706368  1900-01-01 15:59:25.956    B    ACE  5AO05128           500
# 10706379  1900-01-01 15:59:36.976    B     CB  5AO05128          2000
# 10706400  1900-01-01 15:59:47.232    S    ACE  5AO05043           362
# 10706405  1900-01-01 15:59:48.241    S    ACE  5AO05043           463
# 10706408  1900-01-01 15:59:48.525    S    ACE  5AO05043           175
# 10706434  1900-01-01 15:59:55.651    B     CB  5AO05128          3500
# 10706453  1900-01-01 16:00:28.790    B    ACE  5AO05128           500
# 10706454  1900-01-01 16:00:38.327    S     CB  5AO05128           500
# 10706456  1900-01-01 16:00:59.650    S    ACE  5AO05128           500
# 10706460  1900-01-01 16:02:05.567    B    ACE  5AO05043          1000
# 10706461  1900-01-01 16:02:05.581    B    ACE  5AO05043           400
# 10706464  1900-01-01 16:02:06.501    B    ACE  5AO05043           200
# 10706465  1900-01-01 16:02:06.514    B    ACE  5AO05043           100
# 10706466  1900-01-01 16:02:15.906    B    ACE  5AO05128           500
# 10706473  1900-01-01 16:03:09.477    S     CB  5AO05129           300
# 10706478  1900-01-01 16:03:24.372    S     CB  5AO05128           500
# 10706479  1900-01-01 16:03:43.891    S     CB  5AO05128           500
# 10706523  1900-01-01 16:04:48.366    S    ACE  5AO05128           500
# 10706528  1900-01-01 16:14:04.537    S   JAGX  5AO05043          2001
# 10706539  1900-01-01 16:14:59.953    S   UVXY  5AO05043           200
# 10706541  1900-01-01 16:15:00.216    S   UVXY  5AO05043           100
# 10706542  1900-01-01 16:15:05.447    B   UVXY  5AO05043           300
# 10706548  1900-01-01 18:57:39.309    S    ACE  5AO05128           500
# 10706550  1900-01-01 18:57:46.748    S    ACE  5AO05128           500
# 10706572  1900-01-01 19:06:40.645    S    ACE  5AO05128          1000
# 10706581  1900-01-01 19:08:24.397    S    ACE  5AO05128          1000
# 10706592  1900-01-01 19:14:31.906    S    ACE  5AO05128           100
# 10706597  1900-01-01 19:14:51.905    S    ACE  5AO05128          1000
#
#          orderstatus  tif  exec_shares           exec_last_time  \
# 2             UR OUT  DAY        100.0  1900-01-01 07:01:42.870
# 3             UR OUT  DAY        500.0  1900-01-01 07:02:06.000
# 6             UR OUT  DAY        128.0  1900-01-01 07:04:02.000
# 8             PLACED  DAY        150.0  1900-01-01 07:02:22.864
# 9             PLACED  DAY       3331.0  1900-01-01 07:33:59.000
# 32            PLACED  DAY        455.0  1900-01-01 07:06:46.979
# 42            UR OUT  DAY          1.0  1900-01-01 07:08:46.000
# 44            PLACED  DAY        100.0  1900-01-01 07:17:09.000
# 45            PLACED  DAY        100.0  1900-01-01 08:00:00.000
# 49            PLACED  DAY        660.0  1900-01-01 07:09:49.728
# 51            PLACED  DAY        100.0  1900-01-01 07:42:53.000
# 54            PLACED  DAY        200.0  1900-01-01 07:42:38.000
# 60            PLACED  DAY        100.0  1900-01-01 07:22:42.000
# 61            PLACED  DAY        100.0  1900-01-01 07:11:20.813
# 77            UR OUT  DAY        100.0  1900-01-01 07:33:47.000
# 79            PLACED  DAY       1000.0  1900-01-01 08:00:00.000
# 80            UR OUT  DAY        100.0  1900-01-01 07:33:20.000
# 138           UR OUT  DAY        271.0  1900-01-01 07:32:59.465
# 166           PLACED  DAY        900.0  1900-01-01 08:21:39.000
# 168           PLACED  GTC        900.0  1900-01-01 08:21:39.874
# 169           PLACED  DAY        900.0  1900-01-01 08:21:41.429
# 202           PLACED  DAY        300.0  1900-01-01 07:38:51.182
# 209           UR OUT  GTC        245.0  1900-01-01 09:43:35.422
# 210           UR OUT  DAY        100.0  1900-01-01 09:43:35.370
# 233           PLACED  DAY        500.0  1900-01-01 08:21:39.000
# 260           PLACED  IOC       1000.0  1900-01-01 07:41:21.748
# 313           UR OUT  DAY         50.0  1900-01-01 08:00:03.000
# 351           PLACED  DAY       1000.0  1900-01-01 09:35:19.000
# 352           PLACED  DAY       1000.0  1900-01-01 09:35:19.000
# 435           UR OUT  DAY        442.0  1900-01-01 08:00:00.000
# ...              ...  ...          ...                      ...
# 10706321      PLACED  DAY       5000.0  1900-01-01 16:03:57.000
# 10706366      PLACED  DAY       2000.0  1900-01-01 15:59:40.000
# 10706368      PLACED  DAY        500.0  1900-01-01 15:59:55.219
# 10706379      PLACED  DAY       2000.0  1900-01-01 16:03:57.000
# 10706400      PLACED  DAY        362.0  1900-01-01 16:02:02.000
# 10706405      PLACED  DAY        463.0  1900-01-01 16:02:02.000
# 10706408      PLACED  DAY        175.0  1900-01-01 16:02:02.000
# 10706434      PLACED  DAY       3500.0  1900-01-01 16:03:57.000
# 10706453      PLACED  DAY        500.0  1900-01-01 16:00:29.154
# 10706454      PLACED  DAY        500.0  1900-01-01 16:00:38.328
# 10706456      PLACED  DAY        500.0  1900-01-01 16:01:10.038
# 10706460      UR OUT  IOC        600.0  1900-01-01 16:02:05.572
# 10706461      UR OUT  DAY        200.0  1900-01-01 16:02:05.828
# 10706464      UR OUT  IOC        100.0  1900-01-01 16:02:06.504
# 10706465      PLACED  DAY        100.0  1900-01-01 16:02:06.517
# 10706466      PLACED  DAY        500.0  1900-01-01 16:02:16.491
# 10706473      PLACED  DAY        300.0  1900-01-01 16:03:12.210
# 10706478      PLACED  IOC        500.0  1900-01-01 16:03:24.376
# 10706479      PLACED  DAY        500.0  1900-01-01 16:03:43.915
# 10706523      PLACED  DAY        500.0  1900-01-01 16:04:50.539
# 10706528      UR OUT  IOC       1100.0  1900-01-01 16:14:04.543
# 10706539      PLACED  DAY        200.0  1900-01-01 16:15:00.004
# 10706541      PLACED  DAY        100.0  1900-01-01 16:15:00.445
# 10706542      PLACED  IOC        300.0  1900-01-01 16:15:05.452
# 10706548      PLACED  GTC        500.0  1900-01-01 18:58:26.334
# 10706550      PLACED  DAY        500.0  1900-01-01 18:58:26.336
# 10706572      UR OUT  GTC        900.0  1900-01-01 19:06:40.649
# 10706581      UR OUT  GTC        600.0  1900-01-01 19:08:38.473
# 10706592      PLACED  GTC        100.0  1900-01-01 19:30:16.312
# 10706597      PLACED  DAY       1000.0  1900-01-01 19:30:16.312
#
#                 explicit_cxl_time  fill_rate auto_cxl_time  \
# 2         1900-01-01 07:01:45.190   0.117647           NaN
# 3         1900-01-01 07:02:22.848   0.769231           NaN
# 6         1900-01-01 07:08:41.340   0.112775           NaN
# 8                             NaN   1.000000           NaN
# 9                             NaN   1.000000           NaN
# 32                            NaN   1.000000           NaN
# 42        1900-01-01 07:08:50.813   0.000993           NaN
# 44                            NaN   1.000000           NaN
# 45                            NaN   1.000000           NaN
# 49                            NaN   1.000000           NaN
# 51                            NaN   1.000000           NaN
# 54                            NaN   1.000000           NaN
# 60                            NaN   1.000000           NaN
# 61                            NaN   1.000000           NaN
# 77        1900-01-01 07:38:35.715   0.200000           NaN
# 79                            NaN   1.000000           NaN
# 80        1900-01-01 07:33:28.755   0.200000           NaN
# 138       1900-01-01 08:00:35.925   0.271000           NaN
# 166                           NaN   1.000000           NaN
# 168                           NaN   1.000000           NaN
# 169                           NaN   1.000000           NaN
# 202                           NaN   1.000000           NaN
# 209       1900-01-01 09:43:37.663   0.163333           NaN
# 210       1900-01-01 09:43:37.663   0.066667           NaN
# 233                           NaN   1.000000           NaN
# 260                           NaN   1.000000           NaN
# 313       1900-01-01 08:21:42.104   0.033333           NaN
# 351                           NaN   1.000000           NaN
# 352                           NaN   1.000000           NaN
# 435       1900-01-01 08:00:54.255   0.884000           NaN
# ...                           ...        ...           ...
# 10706321                      NaN   1.000000           NaN
# 10706366                      NaN   1.000000           NaN
# 10706368                      NaN   1.000000           NaN
# 10706379                      NaN   1.000000           NaN
# 10706400                      NaN   1.000000           NaN
# 10706405                      NaN   1.000000           NaN
# 10706408                      NaN   1.000000           NaN
# 10706434                      NaN   1.000000           NaN
# 10706453                      NaN   1.000000           NaN
# 10706454                      NaN   1.000000           NaN
# 10706456                      NaN   1.000000           NaN
# 10706460                      NaN   0.600000           NaN
# 10706461  1900-01-01 16:02:07.083   0.500000           NaN
# 10706464                      NaN   0.500000           NaN
# 10706465                      NaN   1.000000           NaN
# 10706466                      NaN   1.000000           NaN
# 10706473                      NaN   1.000000           NaN
# 10706478                      NaN   1.000000           NaN
# 10706479                      NaN   1.000000           NaN
# 10706523                      NaN   1.000000           NaN
# 10706528                      NaN   0.549725           NaN
# 10706539                      NaN   1.000000           NaN
# 10706541                      NaN   1.000000           NaN
# 10706542                      NaN   1.000000           NaN
# 10706548                      NaN   1.000000           NaN
# 10706550                      NaN   1.000000           NaN
# 10706572  1900-01-01 19:06:43.659   0.900000           NaN
# 10706581  1900-01-01 19:14:34.665   0.600000           NaN
# 10706592                      NaN   1.000000           NaN
# 10706597                      NaN   1.000000           NaN
#
#                          cxl_time hidden
# 2         1900-01-01 07:01:45.190  False
# 3         1900-01-01 07:02:22.848  False
# 6         1900-01-01 07:08:41.340  False
# 8                             NaN  False
# 9                             NaN  False
# 32                            NaN  False
# 42        1900-01-01 07:08:50.813  False
# 44                            NaN  False
# 45                            NaN  False
# 49                            NaN  False
# 51                            NaN  False
# 54                            NaN  False
# 60                            NaN  False
# 61                            NaN  False
# 77        1900-01-01 07:38:35.715  False
# 79                            NaN  False
# 80        1900-01-01 07:33:28.755  False
# 138       1900-01-01 08:00:35.925  False
# 166                           NaN  False
# 168                           NaN  False
# 169                           NaN  False
# 202                           NaN  False
# 209       1900-01-01 09:43:37.663  False
# 210       1900-01-01 09:43:37.663  False
# 233                           NaN  False
# 260                           NaN   True
# 313       1900-01-01 08:21:42.104  False
# 351                           NaN  False
# 352                           NaN  False
# 435       1900-01-01 08:00:54.255  False
# ...                           ...    ...
# 10706321                      NaN  False
# 10706366                      NaN  False
# 10706368                      NaN  False
# 10706379                      NaN  False
# 10706400                      NaN  False
# 10706405                      NaN  False
# 10706408                      NaN  False
# 10706434                      NaN  False
# 10706453                      NaN  False
# 10706454                      NaN  False
# 10706456                      NaN  False
# 10706460                      NaN   True
# 10706461  1900-01-01 16:02:07.083  False
# 10706464                      NaN   True
# 10706465                      NaN  False
# 10706466                      NaN  False
# 10706473                      NaN  False
# 10706478                      NaN   True
# 10706479                      NaN  False
# 10706523                      NaN  False
# 10706528                      NaN   True
# 10706539                      NaN  False
# 10706541                      NaN  False
# 10706542                      NaN   True
# 10706548                      NaN  False
# 10706550                      NaN  False
# 10706572  1900-01-01 19:06:43.659  False
# 10706581  1900-01-01 19:14:34.665  False
# 10706592                      NaN  False
# 10706597                      NaN  False
#
# [2120189 rows x 17 columns]
